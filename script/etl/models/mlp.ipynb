# %%
# !pip3 install --user pandas boto3 mysql-connector-python scikit-learn numpy tensorflow
# Out:
# Requirement already satisfied: pandas in c:\python311\lib\site-packages (2.0.0)
# Requirement already satisfied: boto3 in c:\python311\lib\site-packages (1.34.113)
# Requirement already satisfied: mysql-connector-python in c:\python311\lib\site-packages (8.0.32)
# Requirement already satisfied: scikit-learn in c:\python311\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy in c:\python311\lib\site-packages (1.26.4)
# Requirement already satisfied: tensorflow in c:\python311\lib\site-packages (2.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: botocore<1.35.0,>=1.34.113 in c:\python311\lib\site-packages (from boto3) (1.34.113)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\python311\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\python311\lib\site-packages (from boto3) (0.10.1)
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in c:\python311\lib\site-packages (from mysql-connector-python) (3.20.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\python311\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\python311\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python311\lib\site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\python311\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (23.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.29.0)
# Requirement already satisfied: setuptools in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\lucas\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\python311\lib\site-packages (from botocore<1.35.0,>=1.34.113->boto3) (1.26.15)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\python311\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in c:\python311\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\python311\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2022.12.7)
# Requirement already satisfied: markdown>=2.6.8 in c:\python311\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\python311\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\python311\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in c:\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import matplotlib as mpl
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import time
import sys
sys.path.append('../..') # Adiciona o diretório superior ao caminho de importação para acessar funções utilitárias
from functions.db_inserts import * # Importa funções para inserção de dados no banco de dados
from functions.aws_functions import * # Importa funções relacionadas à AWS
from functions.select_cols_functions import * # Importa funções para seleção e processamento de colunas
from tensorflow.keras.regularizers import l2
from sklearn.metrics import mean_absolute_error, cohen_kappa_score
from keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import backend as K

# %%
env_mode = 'prd' # Define o modo de ambiente: 'dev' para desenvolvimento, 'prd' para produção

# %% [markdown]
# ### Lendo arquivo fonte

# %%
bucket_name = "adoptai-trusted-prod-tcc" # Nome do bucket S3 de onde os dados serão carregados

# %%
if env_mode == 'dev':
    # Modo de desenvolvimento: carrega e processa os dados localmente
    source = 'feature_engineering'
    df_trusted = pd.read_csv(f'../../../data/{source}.csv')
    df_trusted = apply_all_rules(df_trusted)
    s3 = [f'{source}.csv', df_trusted]
elif env_mode == 'prd':
    # Modo de produção: carrega e processa os dados a partir do S3
    s3 = s3_csv_to_df(bucket_name)
    df_trusted = s3[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 9
#       6     s3 = [f'{source}.csv', df_trusted]
#       7 elif env_mode == 'prd':
#       8     # Modo de produção: carrega e processa os dados a partir do S3
# ----> 9     s3 = s3_csv_to_df(bucket_name)
#      10     df_trusted = s3[1]
#
# File d:\dev\tcc-artificial-intelligence\script\etl\models\../..\functions\aws_functions.py:13, in s3_csv_to_df(bucket_name)
#      10 def s3_csv_to_df(bucket_name):
#      11     # Cria uma sessão do boto3 utilizando as credenciais fornecidas
#      12     session = boto3.Session(
# ---> 13         aws_access_key_id= u.aws_access_key_id,
#      14         aws_secret_access_key= u.aws_secret_access_key,
#      15         aws_session_token= u.aws_session_token
#      16     )
#      18     # Cria um cliente S3 utilizando a sessão criada
#      19     s3_client = session.client('s3')
#
# AttributeError: module 'util.credentials' has no attribute 'aws_access_key_id'

# %% [markdown]
# ### Utilizando LabelEncoded nas colunas categóricas

# %%
df_trusted = adjust_categoric_values(df_trusted)

# %% [markdown]
# ### Parâmetros de gravação

# %%
nome_fonte = s3[0] # Armazena o nome do arquivo de dados utilizado
nome_modelo = 'MLP' # Define o nome do modelo
parameters = {
    'learning_rate': [
        1e-2,
        1e-3,
        1e-4
    ],
}

# %% [markdown]
# ### Preparativos para executar o modelo

# %%
# Listas para armazenar métricas de desempenho e tempos de execução
accuracy = []
precision = []
recall = []
f1 = []
mae = []
qwk = []

start_times = []
end_times = []

# %%
# Separar as features (x) e os rótulos (y)
x = df_trusted.iloc[:, :-1] # Seleciona todas as colunas, exceto a última, como features
y = df_trusted.iloc[:, -1] # Seleciona a última coluna como rótulo

# %%
# Dividir os dados em conjuntos de treinamento e teste
x_train_full, x_test, y_train_full, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_valid, x_train = x_train_full[:int(len(x_train_full) * 0.1)], x_train_full[int(len(x_train_full) * 0.1):]
y_valid, y_train = y_train_full[:int(len(y_train_full) * 0.1)], y_train_full[int(len(y_train_full) * 0.1):]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_valid = scaler.transform(x_valid)
x_test = scaler.transform(x_test)

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# WARNING:tensorflow:From C:\Users\lucas\AppData\Roaming\Python\Python311\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %% [markdown]
# ###  Rodando modelo Sequencial

# %%
def mae_classification(y_true, y_pred):
    y_pred_labels = K.argmax(y_pred, axis=-1)
    y_true_labels = K.cast(y_true, y_pred_labels.dtype)
    return K.mean(K.abs(y_true_labels - y_pred_labels))

# %%
for learning_rate in parameters['learning_rate']:

    start_time = start_times.append(time.time()) # Registra o tempo de início

    early_stopping = EarlyStopping(patience=10, restore_best_weights=True)

    # Inicializa o modelo com os parâmetros atuais
    model = keras.models.Sequential([
        Dense(32, activation="relu"),
        Dropout(0.3),
        Dense(16, activation="relu"),
        Dropout(0.3),
        Dense(5, activation="softmax")
    ])

    model.compile(loss="sparse_categorical_crossentropy",
                optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
                metrics=["accuracy", mae_classification])

    history = model.fit(
        x_train, y_train,
        epochs=200,
        validation_data=(x_valid, y_valid),
        callbacks=[early_stopping]
    )

    # Fazer previsões no conjunto de teste
    y_pred = model.predict(x_test)
    y_pred_labels = np.argmax(y_pred, axis=1)

    # Calcula e armazena as métricas
    accuracy.append(accuracy_score(y_test, y_pred_labels))
    precision.append(precision_score(y_test, y_pred_labels, average=None))
    recall.append(recall_score(y_test, y_pred_labels, average=None))
    f1.append(f1_score(y_test, y_pred_labels, average=None))
    mae.append(mean_absolute_error(y_test, y_pred_labels))
    qwk.append(cohen_kappa_score(y_test, y_pred_labels, weights='quadratic'))

    end_times.append(time.time()) # Registra o tempo de término
# Out:
# Epoch 1/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2751 - loss: 1.5495 - mae_classification: 0.9965 - val_accuracy: 0.3420 - val_loss: 1.4394 - val_mae_classification: 1.0000
# Epoch 2/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.3199 - loss: 1.4368 - mae_classification: 0.9721 - val_accuracy: 0.3536 - val_loss: 1.4265 - val_mae_classification: 1.0000
# Epoch 3/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.3413 - loss: 1.4267 - mae_classification: 0.9909 - val_accuracy: 0.3578 - val_loss: 1.4253 - val_mae_classification: 1.0000
# Epoch 4/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.3337 - loss: 1.4224 - mae_classification: 0.9899 - val_accuracy: 0.3553 - val_loss: 1.4172 - val_mae_classification: 0.9737
# Epoch 5/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.3412 - loss: 1.4166 - mae_classification: 0.9746 - val_accuracy: 0.3636 - val_loss: 1.4112 - val_mae_classification: 1.0000
# Epoch 6/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.3375 - loss: 1.4137 - mae_classification: 0.9998 - val_accuracy: 0.3653 - val_loss: 1.4121 - val_mae_classification: 1.0000
# Epoch 7/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.3433 - loss: 1.4146 - mae_classification: 0.9732 - val_accuracy: 0.3703 - val_loss: 1.4070 - val_mae_classification: 1.0000
# Epoch 8/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.3463 - loss: 1.4038 - mae_classification: 0.9957 - val_accuracy: 0.3820 - val_loss: 1.4037 - val_mae_classification: 1.0000
# Epoch 9/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.3555 - loss: 1.4051 - mae_classification: 0.9837 - val_accuracy: 0.3837 - val_loss: 1.3995 - val_mae_classification: 1.0000
# Epoch 10/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.3509 - loss: 1.4040 - mae_classification: 0.9963 - val_accuracy: 0.3853 - val_loss: 1.3916 - val_mae_classification: 1.0000
# Epoch 11/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.3510 - loss: 1.4009 - mae_classification: 0.9890 - val_accuracy: 0.3753 - val_loss: 1.3953 - val_mae_classification: 1.0000
# Epoch 12/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.3442 - loss: 1.4042 - mae_classification: 1.0000 - val_accuracy: 0.3620 - val_loss: 1.4090 - val_mae_classification: 1.0000
# Epoch 13/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.3558 - loss: 1.4053 - mae_classification: 0.9843 - val_accuracy: 0.3736 - val_loss: 1.3984 - val_mae_classification: 1.0000
# Epoch 14/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.3598 - loss: 1.3987 - mae_classification: 0.9843 - val_accuracy: 0.3636 - val_loss: 1.3933 - val_mae_classification: 1.0000
# Epoch 15/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.3570 - loss: 1.3941 - mae_classification: 0.9940 - val_accuracy: 0.3812 - val_loss: 1.3874 - val_mae_classification: 1.0000
# Epoch 16/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.3551 - loss: 1.3980 - mae_classification: 0.9908 - val_accuracy: 0.3645 - val_loss: 1.3953 - val_mae_classification: 1.0000
# Epoch 17/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.3613 - loss: 1.3940 - mae_classification: 0.9909 - val_accuracy: 0.3736 - val_loss: 1.3947 - val_mae_classification: 1.0000
# Epoch 18/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.3648 - loss: 1.3934 - mae_classification: 0.9948 - val_accuracy: 0.3711 - val_loss: 1.3928 - val_mae_classification: 1.0000
# Epoch 19/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.3591 - loss: 1.3997 - mae_classification: 0.9991 - val_accuracy: 0.3745 - val_loss: 1.3877 - val_mae_classification: 1.0000
# Epoch 20/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 0.3684 - loss: 1.3929 - mae_classification: 0.9847 - val_accuracy: 0.3636 - val_loss: 1.3916 - val_mae_classification: 1.0000
# Epoch 21/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.3630 - loss: 1.3901 - mae_classification: 0.9929 - val_accuracy: 0.3686 - val_loss: 1.3951 - val_mae_classification: 1.0000
# Epoch 22/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.3615 - loss: 1.3944 - mae_classification: 0.9998 - val_accuracy: 0.3661 - val_loss: 1.3924 - val_mae_classification: 1.0000
# Epoch 23/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.3577 - loss: 1.3950 - mae_classification: 0.9869 - val_accuracy: 0.3561 - val_loss: 1.4003 - val_mae_classification: 1.0000
# Epoch 24/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.3581 - loss: 1.3940 - mae_classification: 0.9950 - val_accuracy: 0.3853 - val_loss: 1.3892 - val_mae_classification: 1.0000
# Epoch 25/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.3602 - loss: 1.3919 - mae_classification: 0.9871 - val_accuracy: 0.3670 - val_loss: 1.3976 - val_mae_classification: 1.0000
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step
# Epoch 1/200
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2198 - loss: 1.7579 - mae_classification: 1.0000 - val_accuracy: 0.2861 - val_loss: 1.4871 - val_mae_classification: 1.0000
# Epoch 2/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - accuracy: 0.2856 - loss: 1.4953 - mae_classification: 1.0000 - val_accuracy: 0.2952 - val_loss: 1.4716 - val_mae_classification: 1.0000
# Epoch 3/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.2978 - loss: 1.4704 - mae_classification: 1.0000 - val_accuracy: 0.3445 - val_loss: 1.4577 - val_mae_classification: 1.0000
# Epoch 4/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.3114 - loss: 1.4494 - mae_classification: 1.0000 - val_accuracy: 0.3394 - val_loss: 1.4467 - val_mae_classification: 1.0000
# Epoch 5/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.3269 - loss: 1.4393 - mae_classification: 1.0000 - val_accuracy: 0.3436 - val_loss: 1.4336 - val_mae_classification: 1.0000
# Epoch 6/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.3261 - loss: 1.4320 - mae_classification: 0.9973 - val_accuracy: 0.3645 - val_loss: 1.4259 - val_mae_classification: 1.0000
# Epoch 7/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.3452 - loss: 1.4225 - mae_classification: 1.0000 - val_accuracy: 0.3595 - val_loss: 1.4219 - val_mae_classification: 1.0000
# Epoch 8/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.3486 - loss: 1.4160 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.4138 - val_mae_classification: 1.0000
# Epoch 9/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.3518 - loss: 1.4112 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4102 - val_mae_classification: 1.0000
# Epoch 10/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.3534 - loss: 1.4077 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.4074 - val_mae_classification: 1.0000
# Epoch 11/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.3542 - loss: 1.4073 - mae_classification: 0.9930 - val_accuracy: 0.3686 - val_loss: 1.4034 - val_mae_classification: 1.0000
# Epoch 12/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.3548 - loss: 1.4020 - mae_classification: 1.0000 - val_accuracy: 0.3736 - val_loss: 1.4010 - val_mae_classification: 1.0000
# Epoch 13/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.3630 - loss: 1.3981 - mae_classification: 1.0000 - val_accuracy: 0.3703 - val_loss: 1.3981 - val_mae_classification: 1.0000
# Epoch 14/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.3638 - loss: 1.3925 - mae_classification: 1.0000 - val_accuracy: 0.3745 - val_loss: 1.3936 - val_mae_classification: 1.0000
# Epoch 15/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.3648 - loss: 1.3898 - mae_classification: 1.0000 - val_accuracy: 0.3736 - val_loss: 1.3924 - val_mae_classification: 1.0000
# Epoch 16/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - accuracy: 0.3651 - loss: 1.3910 - mae_classification: 1.0000 - val_accuracy: 0.3803 - val_loss: 1.3900 - val_mae_classification: 1.0000
# Epoch 17/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.3695 - loss: 1.3888 - mae_classification: 1.0000 - val_accuracy: 0.3803 - val_loss: 1.3890 - val_mae_classification: 1.0000
# Epoch 18/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.3652 - loss: 1.3888 - mae_classification: 1.0000 - val_accuracy: 0.3878 - val_loss: 1.3876 - val_mae_classification: 1.0000
# Epoch 19/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.3698 - loss: 1.3799 - mae_classification: 1.0000 - val_accuracy: 0.3887 - val_loss: 1.3870 - val_mae_classification: 1.0000
# Epoch 20/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.3812 - loss: 1.3798 - mae_classification: 1.0000 - val_accuracy: 0.3795 - val_loss: 1.3864 - val_mae_classification: 1.0000
# Epoch 21/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.3768 - loss: 1.3810 - mae_classification: 1.0000 - val_accuracy: 0.3786 - val_loss: 1.3854 - val_mae_classification: 1.0000
# Epoch 22/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.3660 - loss: 1.3788 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3849 - val_mae_classification: 1.0000
# Epoch 23/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.3764 - loss: 1.3791 - mae_classification: 1.0000 - val_accuracy: 0.3845 - val_loss: 1.3804 - val_mae_classification: 1.0000
# Epoch 24/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.3810 - loss: 1.3766 - mae_classification: 1.0000 - val_accuracy: 0.3903 - val_loss: 1.3810 - val_mae_classification: 1.0000
# Epoch 25/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.3798 - loss: 1.3735 - mae_classification: 1.0000 - val_accuracy: 0.3895 - val_loss: 1.3780 - val_mae_classification: 1.0000
# Epoch 26/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.3722 - loss: 1.3755 - mae_classification: 1.0000 - val_accuracy: 0.3803 - val_loss: 1.3792 - val_mae_classification: 1.0000
# Epoch 27/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.3760 - loss: 1.3777 - mae_classification: 1.0000 - val_accuracy: 0.3878 - val_loss: 1.3772 - val_mae_classification: 1.0000
# Epoch 28/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.3746 - loss: 1.3778 - mae_classification: 1.0000 - val_accuracy: 0.3778 - val_loss: 1.3803 - val_mae_classification: 1.0000
# Epoch 29/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.3789 - loss: 1.3722 - mae_classification: 1.0000 - val_accuracy: 0.3795 - val_loss: 1.3768 - val_mae_classification: 1.0000
# Epoch 30/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.3850 - loss: 1.3663 - mae_classification: 1.0000 - val_accuracy: 0.3820 - val_loss: 1.3775 - val_mae_classification: 1.0000
# Epoch 31/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.3791 - loss: 1.3704 - mae_classification: 1.0000 - val_accuracy: 0.3820 - val_loss: 1.3719 - val_mae_classification: 1.0000
# Epoch 32/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.3770 - loss: 1.3708 - mae_classification: 1.0000 - val_accuracy: 0.3853 - val_loss: 1.3748 - val_mae_classification: 1.0000
# Epoch 33/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.3770 - loss: 1.3705 - mae_classification: 1.0000 - val_accuracy: 0.3820 - val_loss: 1.3747 - val_mae_classification: 1.0000
# Epoch 34/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.3841 - loss: 1.3675 - mae_classification: 1.0000 - val_accuracy: 0.3920 - val_loss: 1.3736 - val_mae_classification: 1.0000
# Epoch 35/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.3777 - loss: 1.3631 - mae_classification: 1.0000 - val_accuracy: 0.3845 - val_loss: 1.3718 - val_mae_classification: 1.0000
# Epoch 36/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.3742 - loss: 1.3747 - mae_classification: 1.0000 - val_accuracy: 0.3795 - val_loss: 1.3730 - val_mae_classification: 1.0000
# Epoch 37/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.3812 - loss: 1.3646 - mae_classification: 1.0000 - val_accuracy: 0.3812 - val_loss: 1.3702 - val_mae_classification: 1.0000
# Epoch 38/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.3805 - loss: 1.3664 - mae_classification: 1.0000 - val_accuracy: 0.3853 - val_loss: 1.3722 - val_mae_classification: 1.0000
# Epoch 39/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.3748 - loss: 1.3664 - mae_classification: 1.0000 - val_accuracy: 0.3812 - val_loss: 1.3710 - val_mae_classification: 1.0000
# Epoch 40/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.3800 - loss: 1.3624 - mae_classification: 1.0000 - val_accuracy: 0.3895 - val_loss: 1.3692 - val_mae_classification: 1.0000
# Epoch 41/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.3802 - loss: 1.3677 - mae_classification: 1.0000 - val_accuracy: 0.3853 - val_loss: 1.3688 - val_mae_classification: 1.0000
# Epoch 42/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.3774 - loss: 1.3658 - mae_classification: 1.0000 - val_accuracy: 0.3778 - val_loss: 1.3683 - val_mae_classification: 1.0000
# Epoch 43/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.3844 - loss: 1.3608 - mae_classification: 1.0000 - val_accuracy: 0.3853 - val_loss: 1.3689 - val_mae_classification: 1.0000
# Epoch 44/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.3799 - loss: 1.3668 - mae_classification: 1.0000 - val_accuracy: 0.3870 - val_loss: 1.3690 - val_mae_classification: 1.0000
# Epoch 45/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.3890 - loss: 1.3595 - mae_classification: 1.0000 - val_accuracy: 0.3878 - val_loss: 1.3700 - val_mae_classification: 1.0000
# Epoch 46/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.3798 - loss: 1.3639 - mae_classification: 1.0000 - val_accuracy: 0.3853 - val_loss: 1.3693 - val_mae_classification: 1.0000
# Epoch 47/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.3869 - loss: 1.3585 - mae_classification: 1.0000 - val_accuracy: 0.3937 - val_loss: 1.3699 - val_mae_classification: 1.0000
# Epoch 48/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.3811 - loss: 1.3606 - mae_classification: 1.0000 - val_accuracy: 0.3887 - val_loss: 1.3706 - val_mae_classification: 1.0000
# Epoch 49/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - accuracy: 0.3817 - loss: 1.3604 - mae_classification: 1.0000 - val_accuracy: 0.3845 - val_loss: 1.3707 - val_mae_classification: 1.0000
# Epoch 50/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.3852 - loss: 1.3581 - mae_classification: 1.0000 - val_accuracy: 0.3987 - val_loss: 1.3703 - val_mae_classification: 1.0000
# Epoch 51/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.3840 - loss: 1.3535 - mae_classification: 1.0000 - val_accuracy: 0.3903 - val_loss: 1.3703 - val_mae_classification: 1.0000
# Epoch 52/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.3855 - loss: 1.3537 - mae_classification: 1.0000 - val_accuracy: 0.3978 - val_loss: 1.3707 - val_mae_classification: 1.0000
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# Epoch 1/200
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2131 - loss: 2.0281 - mae_classification: 1.0000 - val_accuracy: 0.2485 - val_loss: 1.6570 - val_mae_classification: 1.0000
# Epoch 2/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.2376 - loss: 1.7408 - mae_classification: 0.9997 - val_accuracy: 0.2669 - val_loss: 1.5615 - val_mae_classification: 0.9737
# Epoch 3/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.2533 - loss: 1.6391 - mae_classification: 0.9931 - val_accuracy: 0.2802 - val_loss: 1.5241 - val_mae_classification: 0.9737
# Epoch 4/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.2670 - loss: 1.5823 - mae_classification: 0.9940 - val_accuracy: 0.2869 - val_loss: 1.5050 - val_mae_classification: 1.0000
# Epoch 5/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.2628 - loss: 1.5572 - mae_classification: 0.9997 - val_accuracy: 0.2919 - val_loss: 1.4938 - val_mae_classification: 1.0000
# Epoch 6/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.2804 - loss: 1.5259 - mae_classification: 0.9888 - val_accuracy: 0.3044 - val_loss: 1.4861 - val_mae_classification: 1.0000
# Epoch 7/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.2681 - loss: 1.5236 - mae_classification: 1.0000 - val_accuracy: 0.3028 - val_loss: 1.4809 - val_mae_classification: 1.0000
# Epoch 8/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.2839 - loss: 1.5058 - mae_classification: 0.9889 - val_accuracy: 0.3078 - val_loss: 1.4769 - val_mae_classification: 1.0000
# Epoch 9/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.2752 - loss: 1.5070 - mae_classification: 0.9945 - val_accuracy: 0.3119 - val_loss: 1.4732 - val_mae_classification: 1.0000
# Epoch 10/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.2771 - loss: 1.4881 - mae_classification: 1.0000 - val_accuracy: 0.3119 - val_loss: 1.4700 - val_mae_classification: 1.0000
# Epoch 11/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.2872 - loss: 1.4866 - mae_classification: 1.0000 - val_accuracy: 0.3128 - val_loss: 1.4674 - val_mae_classification: 1.0000
# Epoch 12/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.2869 - loss: 1.4834 - mae_classification: 1.0000 - val_accuracy: 0.3144 - val_loss: 1.4652 - val_mae_classification: 1.0000
# Epoch 13/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.2822 - loss: 1.4767 - mae_classification: 0.9945 - val_accuracy: 0.3136 - val_loss: 1.4632 - val_mae_classification: 1.0000
# Epoch 14/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.3017 - loss: 1.4692 - mae_classification: 0.9945 - val_accuracy: 0.3111 - val_loss: 1.4612 - val_mae_classification: 1.0000
# Epoch 15/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.2939 - loss: 1.4656 - mae_classification: 1.0000 - val_accuracy: 0.3178 - val_loss: 1.4594 - val_mae_classification: 1.0000
# Epoch 16/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.3082 - loss: 1.4620 - mae_classification: 0.9945 - val_accuracy: 0.3203 - val_loss: 1.4576 - val_mae_classification: 1.0000
# Epoch 17/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.2917 - loss: 1.4663 - mae_classification: 0.9946 - val_accuracy: 0.3261 - val_loss: 1.4564 - val_mae_classification: 1.0000
# Epoch 18/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.3090 - loss: 1.4596 - mae_classification: 1.0000 - val_accuracy: 0.3244 - val_loss: 1.4551 - val_mae_classification: 1.0000
# Epoch 19/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.3075 - loss: 1.4513 - mae_classification: 1.0000 - val_accuracy: 0.3236 - val_loss: 1.4536 - val_mae_classification: 1.0000
# Epoch 20/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.3019 - loss: 1.4584 - mae_classification: 1.0000 - val_accuracy: 0.3286 - val_loss: 1.4524 - val_mae_classification: 1.0000
# Epoch 21/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.3091 - loss: 1.4494 - mae_classification: 1.0000 - val_accuracy: 0.3311 - val_loss: 1.4514 - val_mae_classification: 1.0000
# Epoch 22/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.3041 - loss: 1.4532 - mae_classification: 1.0000 - val_accuracy: 0.3311 - val_loss: 1.4505 - val_mae_classification: 1.0000
# Epoch 23/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.3081 - loss: 1.4509 - mae_classification: 1.0000 - val_accuracy: 0.3286 - val_loss: 1.4494 - val_mae_classification: 1.0000
# Epoch 24/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.3006 - loss: 1.4500 - mae_classification: 1.0000 - val_accuracy: 0.3261 - val_loss: 1.4482 - val_mae_classification: 1.0000
# Epoch 25/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.3074 - loss: 1.4460 - mae_classification: 1.0000 - val_accuracy: 0.3269 - val_loss: 1.4470 - val_mae_classification: 1.0000
# Epoch 26/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.3150 - loss: 1.4451 - mae_classification: 1.0000 - val_accuracy: 0.3311 - val_loss: 1.4461 - val_mae_classification: 1.0000
# Epoch 27/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.3031 - loss: 1.4435 - mae_classification: 1.0000 - val_accuracy: 0.3353 - val_loss: 1.4451 - val_mae_classification: 1.0000
# Epoch 28/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.3159 - loss: 1.4408 - mae_classification: 1.0000 - val_accuracy: 0.3344 - val_loss: 1.4441 - val_mae_classification: 1.0000
# Epoch 29/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.3161 - loss: 1.4401 - mae_classification: 1.0000 - val_accuracy: 0.3344 - val_loss: 1.4435 - val_mae_classification: 1.0000
# Epoch 30/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.3024 - loss: 1.4453 - mae_classification: 1.0000 - val_accuracy: 0.3420 - val_loss: 1.4430 - val_mae_classification: 1.0000
# Epoch 31/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.3127 - loss: 1.4375 - mae_classification: 1.0000 - val_accuracy: 0.3436 - val_loss: 1.4417 - val_mae_classification: 1.0000
# Epoch 32/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.3141 - loss: 1.4384 - mae_classification: 1.0000 - val_accuracy: 0.3436 - val_loss: 1.4407 - val_mae_classification: 1.0000
# Epoch 33/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.3173 - loss: 1.4386 - mae_classification: 0.9947 - val_accuracy: 0.3411 - val_loss: 1.4401 - val_mae_classification: 1.0000
# Epoch 34/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.3234 - loss: 1.4367 - mae_classification: 1.0000 - val_accuracy: 0.3436 - val_loss: 1.4394 - val_mae_classification: 1.0000
# Epoch 35/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.3294 - loss: 1.4335 - mae_classification: 1.0000 - val_accuracy: 0.3478 - val_loss: 1.4387 - val_mae_classification: 1.0000
# Epoch 36/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.3193 - loss: 1.4350 - mae_classification: 1.0000 - val_accuracy: 0.3436 - val_loss: 1.4380 - val_mae_classification: 1.0000
# Epoch 37/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.3271 - loss: 1.4317 - mae_classification: 1.0000 - val_accuracy: 0.3453 - val_loss: 1.4371 - val_mae_classification: 1.0000
# Epoch 38/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.3194 - loss: 1.4336 - mae_classification: 1.0000 - val_accuracy: 0.3461 - val_loss: 1.4363 - val_mae_classification: 1.0000
# Epoch 39/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.3268 - loss: 1.4302 - mae_classification: 1.0000 - val_accuracy: 0.3470 - val_loss: 1.4355 - val_mae_classification: 1.0000
# Epoch 40/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.3250 - loss: 1.4295 - mae_classification: 1.0000 - val_accuracy: 0.3461 - val_loss: 1.4348 - val_mae_classification: 1.0000
# Epoch 41/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.3253 - loss: 1.4298 - mae_classification: 1.0000 - val_accuracy: 0.3495 - val_loss: 1.4338 - val_mae_classification: 1.0000
# Epoch 42/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.3315 - loss: 1.4230 - mae_classification: 1.0000 - val_accuracy: 0.3470 - val_loss: 1.4332 - val_mae_classification: 1.0000
# Epoch 43/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.3347 - loss: 1.4276 - mae_classification: 1.0000 - val_accuracy: 0.3486 - val_loss: 1.4324 - val_mae_classification: 1.0000
# Epoch 44/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.3249 - loss: 1.4285 - mae_classification: 1.0000 - val_accuracy: 0.3520 - val_loss: 1.4316 - val_mae_classification: 1.0000
# Epoch 45/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.3314 - loss: 1.4212 - mae_classification: 1.0000 - val_accuracy: 0.3528 - val_loss: 1.4302 - val_mae_classification: 1.0000
# Epoch 46/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.3330 - loss: 1.4196 - mae_classification: 1.0000 - val_accuracy: 0.3586 - val_loss: 1.4292 - val_mae_classification: 1.0000
# Epoch 47/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.3357 - loss: 1.4161 - mae_classification: 1.0000 - val_accuracy: 0.3586 - val_loss: 1.4287 - val_mae_classification: 1.0000
# Epoch 48/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.3270 - loss: 1.4245 - mae_classification: 1.0000 - val_accuracy: 0.3603 - val_loss: 1.4280 - val_mae_classification: 1.0000
# Epoch 49/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.3272 - loss: 1.4231 - mae_classification: 1.0000 - val_accuracy: 0.3603 - val_loss: 1.4272 - val_mae_classification: 1.0000
# Epoch 50/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.3325 - loss: 1.4186 - mae_classification: 1.0000 - val_accuracy: 0.3603 - val_loss: 1.4264 - val_mae_classification: 1.0000
# Epoch 51/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.3346 - loss: 1.4224 - mae_classification: 1.0000 - val_accuracy: 0.3586 - val_loss: 1.4259 - val_mae_classification: 1.0000
# Epoch 52/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.3363 - loss: 1.4218 - mae_classification: 1.0000 - val_accuracy: 0.3595 - val_loss: 1.4252 - val_mae_classification: 1.0000
# Epoch 53/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.3343 - loss: 1.4230 - mae_classification: 1.0000 - val_accuracy: 0.3620 - val_loss: 1.4247 - val_mae_classification: 1.0000
# Epoch 54/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.3334 - loss: 1.4218 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4243 - val_mae_classification: 1.0000
# Epoch 55/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.3349 - loss: 1.4168 - mae_classification: 1.0000 - val_accuracy: 0.3678 - val_loss: 1.4232 - val_mae_classification: 1.0000
# Epoch 56/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.3421 - loss: 1.4133 - mae_classification: 1.0000 - val_accuracy: 0.3636 - val_loss: 1.4219 - val_mae_classification: 1.0000
# Epoch 57/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.3405 - loss: 1.4135 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4213 - val_mae_classification: 1.0000
# Epoch 58/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.3366 - loss: 1.4103 - mae_classification: 0.9946 - val_accuracy: 0.3703 - val_loss: 1.4210 - val_mae_classification: 1.0000
# Epoch 59/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.3490 - loss: 1.4121 - mae_classification: 1.0000 - val_accuracy: 0.3703 - val_loss: 1.4205 - val_mae_classification: 1.0000
# Epoch 60/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.3421 - loss: 1.4170 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4199 - val_mae_classification: 1.0000
# Epoch 61/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.3435 - loss: 1.4138 - mae_classification: 1.0000 - val_accuracy: 0.3745 - val_loss: 1.4195 - val_mae_classification: 1.0000
# Epoch 62/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.3343 - loss: 1.4194 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.4188 - val_mae_classification: 1.0000
# Epoch 63/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.3446 - loss: 1.4138 - mae_classification: 1.0000 - val_accuracy: 0.3728 - val_loss: 1.4188 - val_mae_classification: 1.0000
# Epoch 64/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.3389 - loss: 1.4196 - mae_classification: 1.0000 - val_accuracy: 0.3728 - val_loss: 1.4184 - val_mae_classification: 1.0000
# Epoch 65/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.3447 - loss: 1.4123 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.4177 - val_mae_classification: 1.0000
# Epoch 66/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.3431 - loss: 1.4189 - mae_classification: 1.0000 - val_accuracy: 0.3661 - val_loss: 1.4170 - val_mae_classification: 1.0000
# Epoch 67/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.3404 - loss: 1.4130 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4167 - val_mae_classification: 1.0000
# Epoch 68/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.3424 - loss: 1.4124 - mae_classification: 1.0000 - val_accuracy: 0.3661 - val_loss: 1.4159 - val_mae_classification: 1.0000
# Epoch 69/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.3371 - loss: 1.4142 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4157 - val_mae_classification: 1.0000
# Epoch 70/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - accuracy: 0.3383 - loss: 1.4120 - mae_classification: 1.0000 - val_accuracy: 0.3628 - val_loss: 1.4153 - val_mae_classification: 1.0000
# Epoch 71/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.3547 - loss: 1.4067 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.4147 - val_mae_classification: 1.0000
# Epoch 72/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.3449 - loss: 1.4096 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4138 - val_mae_classification: 1.0000
# Epoch 73/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.3497 - loss: 1.4076 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4135 - val_mae_classification: 1.0000
# Epoch 74/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.3439 - loss: 1.4121 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4133 - val_mae_classification: 1.0000
# Epoch 75/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.3388 - loss: 1.4054 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4127 - val_mae_classification: 1.0000
# Epoch 76/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.3436 - loss: 1.4045 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4123 - val_mae_classification: 1.0000
# Epoch 77/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.3491 - loss: 1.4051 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4119 - val_mae_classification: 1.0000
# Epoch 78/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.3593 - loss: 1.4007 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4118 - val_mae_classification: 1.0000
# Epoch 79/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.3514 - loss: 1.4074 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4111 - val_mae_classification: 1.0000
# Epoch 80/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.3557 - loss: 1.4040 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4107 - val_mae_classification: 1.0000
# Epoch 81/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.3417 - loss: 1.4076 - mae_classification: 1.0000 - val_accuracy: 0.3678 - val_loss: 1.4104 - val_mae_classification: 1.0000
# Epoch 82/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.3492 - loss: 1.4078 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.4098 - val_mae_classification: 1.0000
# Epoch 83/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.3568 - loss: 1.4031 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4093 - val_mae_classification: 1.0000
# Epoch 84/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.3408 - loss: 1.4101 - mae_classification: 1.0000 - val_accuracy: 0.3703 - val_loss: 1.4089 - val_mae_classification: 1.0000
# Epoch 85/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.3421 - loss: 1.4050 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4082 - val_mae_classification: 1.0000
# Epoch 86/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.3481 - loss: 1.4058 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4081 - val_mae_classification: 1.0000
# Epoch 87/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.3416 - loss: 1.4008 - mae_classification: 1.0000 - val_accuracy: 0.3661 - val_loss: 1.4074 - val_mae_classification: 1.0000
# Epoch 88/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.3452 - loss: 1.4063 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4075 - val_mae_classification: 1.0000
# Epoch 89/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.3415 - loss: 1.4013 - mae_classification: 0.9946 - val_accuracy: 0.3686 - val_loss: 1.4073 - val_mae_classification: 1.0000
# Epoch 90/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.3452 - loss: 1.4040 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4070 - val_mae_classification: 1.0000
# Epoch 91/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.3525 - loss: 1.3946 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4063 - val_mae_classification: 1.0000
# Epoch 92/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.3491 - loss: 1.4029 - mae_classification: 0.9944 - val_accuracy: 0.3636 - val_loss: 1.4060 - val_mae_classification: 1.0000
# Epoch 93/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.3636 - loss: 1.3972 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4058 - val_mae_classification: 1.0000
# Epoch 94/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.3554 - loss: 1.3984 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.4052 - val_mae_classification: 1.0000
# Epoch 95/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.3528 - loss: 1.4055 - mae_classification: 1.0000 - val_accuracy: 0.3703 - val_loss: 1.4048 - val_mae_classification: 1.0000
# Epoch 96/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.3538 - loss: 1.4011 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4048 - val_mae_classification: 1.0000
# Epoch 97/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3602 - loss: 1.4021 - mae_classification: 1.0000 - val_accuracy: 0.3661 - val_loss: 1.4044 - val_mae_classification: 1.0000
# Epoch 98/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.3514 - loss: 1.3999 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4041 - val_mae_classification: 1.0000
# Epoch 99/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.3642 - loss: 1.4000 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4038 - val_mae_classification: 1.0000
# Epoch 100/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.3579 - loss: 1.3949 - mae_classification: 1.0000 - val_accuracy: 0.3678 - val_loss: 1.4036 - val_mae_classification: 1.0000
# Epoch 101/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.3572 - loss: 1.4005 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4030 - val_mae_classification: 1.0000
# Epoch 102/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.3579 - loss: 1.3974 - mae_classification: 1.0000 - val_accuracy: 0.3670 - val_loss: 1.4027 - val_mae_classification: 1.0000
# Epoch 103/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.3564 - loss: 1.3969 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4027 - val_mae_classification: 1.0000
# Epoch 104/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.3567 - loss: 1.3999 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4027 - val_mae_classification: 1.0000
# Epoch 105/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.3531 - loss: 1.3973 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4018 - val_mae_classification: 1.0000
# Epoch 106/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.3516 - loss: 1.3934 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4010 - val_mae_classification: 1.0000
# Epoch 107/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.3548 - loss: 1.3895 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.4008 - val_mae_classification: 1.0000
# Epoch 108/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.3600 - loss: 1.3989 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.4012 - val_mae_classification: 1.0000
# Epoch 109/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.3528 - loss: 1.3951 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4012 - val_mae_classification: 1.0000
# Epoch 110/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.3508 - loss: 1.4006 - mae_classification: 1.0000 - val_accuracy: 0.3653 - val_loss: 1.4009 - val_mae_classification: 1.0000
# Epoch 111/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.3586 - loss: 1.3956 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.4003 - val_mae_classification: 1.0000
# Epoch 112/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.3592 - loss: 1.3973 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.4005 - val_mae_classification: 1.0000
# Epoch 113/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.3595 - loss: 1.4008 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.4002 - val_mae_classification: 1.0000
# Epoch 114/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - accuracy: 0.3609 - loss: 1.3898 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.4000 - val_mae_classification: 1.0000
# Epoch 115/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.3582 - loss: 1.3934 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3994 - val_mae_classification: 1.0000
# Epoch 116/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.3567 - loss: 1.3917 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.3995 - val_mae_classification: 1.0000
# Epoch 117/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.3586 - loss: 1.3950 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.3995 - val_mae_classification: 1.0000
# Epoch 118/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.3631 - loss: 1.3949 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3991 - val_mae_classification: 1.0000
# Epoch 119/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.3590 - loss: 1.3973 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.3990 - val_mae_classification: 1.0000
# Epoch 120/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.3661 - loss: 1.3919 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3984 - val_mae_classification: 1.0000
# Epoch 121/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - accuracy: 0.3599 - loss: 1.3931 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.3985 - val_mae_classification: 1.0000
# Epoch 122/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.3590 - loss: 1.3961 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.3984 - val_mae_classification: 1.0000
# Epoch 123/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.3630 - loss: 1.3912 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.3982 - val_mae_classification: 1.0000
# Epoch 124/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.3604 - loss: 1.3901 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.3978 - val_mae_classification: 1.0000
# Epoch 125/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.3596 - loss: 1.3927 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3978 - val_mae_classification: 1.0000
# Epoch 126/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.3548 - loss: 1.3880 - mae_classification: 1.0000 - val_accuracy: 0.3745 - val_loss: 1.3972 - val_mae_classification: 1.0000
# Epoch 127/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - accuracy: 0.3534 - loss: 1.3934 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3972 - val_mae_classification: 1.0000
# Epoch 128/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.3604 - loss: 1.3863 - mae_classification: 1.0000 - val_accuracy: 0.3761 - val_loss: 1.3971 - val_mae_classification: 1.0000
# Epoch 129/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.3540 - loss: 1.3932 - mae_classification: 1.0000 - val_accuracy: 0.3761 - val_loss: 1.3971 - val_mae_classification: 1.0000
# Epoch 130/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.3658 - loss: 1.3872 - mae_classification: 1.0000 - val_accuracy: 0.3745 - val_loss: 1.3968 - val_mae_classification: 1.0000
# Epoch 131/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.3592 - loss: 1.3850 - mae_classification: 1.0000 - val_accuracy: 0.3761 - val_loss: 1.3967 - val_mae_classification: 1.0000
# Epoch 132/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.3647 - loss: 1.3891 - mae_classification: 1.0000 - val_accuracy: 0.3761 - val_loss: 1.3960 - val_mae_classification: 1.0000
# Epoch 133/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.3598 - loss: 1.3896 - mae_classification: 1.0000 - val_accuracy: 0.3761 - val_loss: 1.3958 - val_mae_classification: 1.0000
# Epoch 134/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.3657 - loss: 1.3951 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3963 - val_mae_classification: 1.0000
# Epoch 135/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.3653 - loss: 1.3886 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3958 - val_mae_classification: 1.0000
# Epoch 136/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.3642 - loss: 1.3835 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3953 - val_mae_classification: 1.0000
# Epoch 137/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.3620 - loss: 1.3880 - mae_classification: 1.0000 - val_accuracy: 0.3770 - val_loss: 1.3949 - val_mae_classification: 1.0000
# Epoch 138/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.3625 - loss: 1.3863 - mae_classification: 1.0000 - val_accuracy: 0.3736 - val_loss: 1.3950 - val_mae_classification: 1.0000
# Epoch 139/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.3709 - loss: 1.3881 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3946 - val_mae_classification: 1.0000
# Epoch 140/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - accuracy: 0.3579 - loss: 1.3875 - mae_classification: 1.0000 - val_accuracy: 0.3703 - val_loss: 1.3944 - val_mae_classification: 1.0000
# Epoch 141/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.3692 - loss: 1.3866 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3937 - val_mae_classification: 1.0000
# Epoch 142/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.3636 - loss: 1.3847 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3933 - val_mae_classification: 1.0000
# Epoch 143/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.3660 - loss: 1.3857 - mae_classification: 1.0000 - val_accuracy: 0.3761 - val_loss: 1.3934 - val_mae_classification: 1.0000
# Epoch 144/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.3636 - loss: 1.3813 - mae_classification: 1.0000 - val_accuracy: 0.3736 - val_loss: 1.3934 - val_mae_classification: 1.0000
# Epoch 145/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.3599 - loss: 1.3896 - mae_classification: 1.0000 - val_accuracy: 0.3736 - val_loss: 1.3932 - val_mae_classification: 1.0000
# Epoch 146/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.3638 - loss: 1.3853 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3933 - val_mae_classification: 1.0000
# Epoch 147/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.3663 - loss: 1.3843 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3932 - val_mae_classification: 1.0000
# Epoch 148/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.3602 - loss: 1.3808 - mae_classification: 1.0000 - val_accuracy: 0.3778 - val_loss: 1.3931 - val_mae_classification: 1.0000
# Epoch 149/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.3662 - loss: 1.3878 - mae_classification: 1.0000 - val_accuracy: 0.3770 - val_loss: 1.3927 - val_mae_classification: 1.0000
# Epoch 150/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.3596 - loss: 1.3878 - mae_classification: 1.0000 - val_accuracy: 0.3736 - val_loss: 1.3925 - val_mae_classification: 1.0000
# Epoch 151/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.3686 - loss: 1.3868 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3920 - val_mae_classification: 1.0000
# Epoch 152/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.3572 - loss: 1.3885 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3919 - val_mae_classification: 1.0000
# Epoch 153/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.3693 - loss: 1.3870 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3918 - val_mae_classification: 1.0000
# Epoch 154/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.3598 - loss: 1.3859 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.3919 - val_mae_classification: 1.0000
# Epoch 155/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.3616 - loss: 1.3810 - mae_classification: 1.0000 - val_accuracy: 0.3736 - val_loss: 1.3913 - val_mae_classification: 1.0000
# Epoch 156/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.3703 - loss: 1.3828 - mae_classification: 1.0000 - val_accuracy: 0.3728 - val_loss: 1.3909 - val_mae_classification: 1.0000
# Epoch 157/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.3672 - loss: 1.3804 - mae_classification: 1.0000 - val_accuracy: 0.3745 - val_loss: 1.3907 - val_mae_classification: 1.0000
# Epoch 158/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.3657 - loss: 1.3846 - mae_classification: 1.0000 - val_accuracy: 0.3745 - val_loss: 1.3914 - val_mae_classification: 1.0000
# Epoch 159/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.3623 - loss: 1.3820 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3911 - val_mae_classification: 1.0000
# Epoch 160/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.3677 - loss: 1.3853 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3911 - val_mae_classification: 1.0000
# Epoch 161/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.3609 - loss: 1.3840 - mae_classification: 1.0000 - val_accuracy: 0.3761 - val_loss: 1.3906 - val_mae_classification: 1.0000
# Epoch 162/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.3641 - loss: 1.3876 - mae_classification: 1.0000 - val_accuracy: 0.3736 - val_loss: 1.3905 - val_mae_classification: 1.0000
# Epoch 163/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.3671 - loss: 1.3851 - mae_classification: 1.0000 - val_accuracy: 0.3736 - val_loss: 1.3900 - val_mae_classification: 1.0000
# Epoch 164/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.3586 - loss: 1.3868 - mae_classification: 1.0000 - val_accuracy: 0.3745 - val_loss: 1.3903 - val_mae_classification: 1.0000
# Epoch 165/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.3681 - loss: 1.3833 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3903 - val_mae_classification: 1.0000
# Epoch 166/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.3670 - loss: 1.3774 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3900 - val_mae_classification: 1.0000
# Epoch 167/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.3702 - loss: 1.3826 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.3900 - val_mae_classification: 1.0000
# Epoch 168/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.3755 - loss: 1.3802 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.3899 - val_mae_classification: 1.0000
# Epoch 169/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.3739 - loss: 1.3798 - mae_classification: 1.0000 - val_accuracy: 0.3678 - val_loss: 1.3899 - val_mae_classification: 1.0000
# Epoch 170/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.3631 - loss: 1.3804 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.3899 - val_mae_classification: 1.0000
# Epoch 171/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.3636 - loss: 1.3835 - mae_classification: 1.0000 - val_accuracy: 0.3678 - val_loss: 1.3897 - val_mae_classification: 1.0000
# Epoch 172/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.3662 - loss: 1.3865 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.3893 - val_mae_classification: 1.0000
# Epoch 173/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.3701 - loss: 1.3871 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.3892 - val_mae_classification: 1.0000
# Epoch 174/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.3660 - loss: 1.3816 - mae_classification: 1.0000 - val_accuracy: 0.3661 - val_loss: 1.3889 - val_mae_classification: 1.0000
# Epoch 175/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.3662 - loss: 1.3815 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.3885 - val_mae_classification: 1.0000
# Epoch 176/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.3708 - loss: 1.3757 - mae_classification: 1.0000 - val_accuracy: 0.3645 - val_loss: 1.3883 - val_mae_classification: 1.0000
# Epoch 177/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.3761 - loss: 1.3790 - mae_classification: 1.0000 - val_accuracy: 0.3661 - val_loss: 1.3884 - val_mae_classification: 1.0000
# Epoch 178/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.3676 - loss: 1.3895 - mae_classification: 1.0000 - val_accuracy: 0.3670 - val_loss: 1.3881 - val_mae_classification: 1.0000
# Epoch 179/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.3700 - loss: 1.3807 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.3879 - val_mae_classification: 1.0000
# Epoch 180/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3612 - loss: 1.3868 - mae_classification: 1.0000 - val_accuracy: 0.3728 - val_loss: 1.3883 - val_mae_classification: 1.0000
# Epoch 181/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.3708 - loss: 1.3777 - mae_classification: 1.0000 - val_accuracy: 0.3703 - val_loss: 1.3874 - val_mae_classification: 1.0000
# Epoch 182/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.3720 - loss: 1.3772 - mae_classification: 1.0000 - val_accuracy: 0.3703 - val_loss: 1.3874 - val_mae_classification: 1.0000
# Epoch 183/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.3736 - loss: 1.3809 - mae_classification: 1.0000 - val_accuracy: 0.3686 - val_loss: 1.3873 - val_mae_classification: 1.0000
# Epoch 184/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.3648 - loss: 1.3780 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.3869 - val_mae_classification: 1.0000
# Epoch 185/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.3685 - loss: 1.3805 - mae_classification: 1.0000 - val_accuracy: 0.3678 - val_loss: 1.3868 - val_mae_classification: 1.0000
# Epoch 186/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.3650 - loss: 1.3758 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3868 - val_mae_classification: 1.0000
# Epoch 187/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.3645 - loss: 1.3820 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.3863 - val_mae_classification: 1.0000
# Epoch 188/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.3710 - loss: 1.3821 - mae_classification: 1.0000 - val_accuracy: 0.3753 - val_loss: 1.3859 - val_mae_classification: 1.0000
# Epoch 189/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.3686 - loss: 1.3759 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3861 - val_mae_classification: 1.0000
# Epoch 190/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.3712 - loss: 1.3773 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.3861 - val_mae_classification: 1.0000
# Epoch 191/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.3845 - loss: 1.3724 - mae_classification: 1.0000 - val_accuracy: 0.3728 - val_loss: 1.3861 - val_mae_classification: 1.0000
# Epoch 192/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.3695 - loss: 1.3851 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.3862 - val_mae_classification: 1.0000
# Epoch 193/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.3701 - loss: 1.3775 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.3859 - val_mae_classification: 1.0000
# Epoch 194/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - accuracy: 0.3666 - loss: 1.3861 - mae_classification: 1.0000 - val_accuracy: 0.3703 - val_loss: 1.3856 - val_mae_classification: 1.0000
# Epoch 195/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.3699 - loss: 1.3769 - mae_classification: 1.0000 - val_accuracy: 0.3720 - val_loss: 1.3852 - val_mae_classification: 1.0000
# Epoch 196/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.3673 - loss: 1.3780 - mae_classification: 1.0000 - val_accuracy: 0.3711 - val_loss: 1.3851 - val_mae_classification: 1.0000
# Epoch 197/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.3724 - loss: 1.3788 - mae_classification: 1.0000 - val_accuracy: 0.3761 - val_loss: 1.3850 - val_mae_classification: 1.0000
# Epoch 198/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.3663 - loss: 1.3817 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.3849 - val_mae_classification: 1.0000
# Epoch 199/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.3726 - loss: 1.3736 - mae_classification: 1.0000 - val_accuracy: 0.3695 - val_loss: 1.3844 - val_mae_classification: 1.0000
# Epoch 200/200
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - accuracy: 0.3745 - loss: 1.3780 - mae_classification: 1.0000 - val_accuracy: 0.3728 - val_loss: 1.3846 - val_mae_classification: 1.0000
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Obtendo métricas de desempenho

# %%
# Armazena as métricas calculadas
metrics = {
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1_score': f1
}

# %% [markdown]
# ### Gravando dados no banco

# %%
# Prepara os dados para inserção no banco de dados
model = {'nome_modelo': nome_modelo, 'nome_fonte': nome_fonte}
execution = {
    'accuracy': accuracy, 
    'mae': mae,
    'qwk': qwk,
    'start_time': start_times, 
    'end_time': end_times
    }
hyperparams = parameters
desempenho = {
    'precision_values': metrics['precision'], 
    'recall_values': metrics['recall'], 
    'f1_values': metrics['f1_score']
    }

# %%
# Insere os valores calculados nas tabelas do banco de dados
insert_values(model, execution, hyperparams, desempenho, env=env_mode)
# Out:
# Executando em dev
# Registros inseridos em dev
